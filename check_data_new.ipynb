# %%
import pandas as pd

# 1. โหลดข้อมูลใหม่ (เปลี่ยนชื่อไฟล์ตรงนี้)
file_name = 'zeus_dataset_combined_new.csv'
print(f"กำลังโหลดข้อมูลจาก: {file_name}")
df = pd.read_csv(file_name)

# 2. ดูภาพรวม
print("\n--- 1. จำนวนข้อมูล (Rows x Columns) ---")
print(df.shape)

print("\n--- 2. รายชื่อคอลัมน์ (Columns) ---")
print(df.columns.tolist())

print("\n--- 3. เช็คค่าว่าง (Missing Values) ---")
print(df.isnull().sum())

print("\n--- 4. ดูหน้าตาข้อมูล 5 บรรทัดแรก ---")
print(df.head())
# Out:
# กำลังโหลดข้อมูลจาก: zeus_dataset_combined_new.csv
#
# --- 1. จำนวนข้อมูล (Rows x Columns) ---
# (9475, 26)
#
# --- 2. รายชื่อคอลัมน์ (Columns) ---
# ['unix_time', 'timezone', 'datetime', 'station_id', 'unk1', 'unk2', 'unk3', 'lat', 'long', 'rain', 'temp', 'humidity', 'pressure', 'wind_speed', 'wind_dir', 'uv', 'co2', 'pm1', 'pm25', 'pm4', 'pm10', 'light_r', 'light_g', 'light_b', 'light_ir', 'light_vis']
#
# --- 3. เช็คค่าว่าง (Missing Values) ---
# unix_time     0
# timezone      0
# datetime      0
# station_id    0
# unk1          0
# unk2          0
# unk3          0
# lat           0
# long          0
# rain          0
# temp          0
# humidity      0
# pressure      0
# wind_speed    0
# wind_dir      0
# uv            0
# co2           0
# pm1           0
# pm25          0
# pm4           0
# pm10          0
# light_r       0
# light_g       0
# light_b       0
# light_ir      0
# light_vis     0
# dtype: int64
#
# --- 4. ดูหน้าตาข้อมูล 5 บรรทัดแรก ---
# ...
